# %%
import stable_baselines3
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import PPO
from gym.wrappers import GrayScaleObservation
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import time
from matplotlib import pyplot as plt
from nes_py.wrappers import JoypadSpace
import os

# %%
# 保存最优模型
monitor_dir = r'./monitor_log/'
os.makedirs(monitor_dir,exist_ok=True)
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)
env = GrayScaleObservation(env,keep_dim=True)
env = Monitor(env, monitor_dir)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, 4,channels_order='last')

# %%
import os

import numpy as np

from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.results_plotter import load_results, ts2xy
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq, save_model_dir, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.save_path = os.path.join(save_model_dir, "best_model/")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:
            print('self.n_calls: ', self.n_calls)
            model_path = os.path.join(self.save_path, 'model_{}'.format(self.n_calls))
            self.model.save(model_path)
        return True

# %%
learning_rate = 1e-6
n_steps = 128
tensorboard_log = r'./tensorboard_log/'
model = PPO("CnnPolicy", env, verbose=1,
        learning_rate=learning_rate,
        n_steps=n_steps,tensorboard_log=tensorboard_log
)

save_model_dir = r'./monitor_log/'
callback1 = SaveOnBestTrainingRewardCallback(check_freq=1000, save_model_dir=save_model_dir)

model.learn(total_timesteps=5000,callback=callback1)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./tensorboard_log/PPO_1
# ----------------------------
# | time/              |     |
# |    fps             | 39  |
# |    iterations      | 1   |
# |    time_elapsed    | 3   |
# |    total_timesteps | 128 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 2.742745e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00226     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 210          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -2.57e-05    |
# |    value_loss           | 466          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 3             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 384           |
# | train/                  |               |
# |    approx_kl            | 1.5227124e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00576      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 684           |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -2.05e-05     |
# |    value_loss           | 1.52e+03      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 512         |
# | train/                  |             |
# |    approx_kl            | 3.60189e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.00418     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 28.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000227   |
# |    value_loss           | 62.2        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 54            |
# |    iterations           | 5             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 640           |
# | train/                  |               |
# |    approx_kl            | 2.5471672e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0338        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.586         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000263     |
# |    value_loss           | 2.04          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 6            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 768          |
# | train/                  |              |
# |    approx_kl            | 5.364418e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00945      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.125        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -6.04e-05    |
# |    value_loss           | 0.894        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 7           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 896         |
# | train/                  |             |
# |    approx_kl            | 9.85805e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | -0.0126     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.132       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -5.7e-05    |
# |    value_loss           | 0.526       |
# -----------------------------------------
# self.n_calls:  1000
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 8           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 9.55537e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.00811     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.102       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -8.21e-05   |
# |    value_loss           | 0.482       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 9             |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 1152          |
# | train/                  |               |
# |    approx_kl            | 6.2724575e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00102      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.133         |
# |    n_updates            | 80            |
# |    policy_gradient_loss | 1.95e-05      |
# |    value_loss           | 0.573         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 10           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 1280         |
# | train/                  |              |
# |    approx_kl            | 3.585592e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.0435      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.101        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -2.06e-05    |
# |    value_loss           | 0.281        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 57            |
# |    iterations           | 11            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 1408          |
# | train/                  |               |
# |    approx_kl            | 3.3387914e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0151        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0487        |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -2.85e-05     |
# |    value_loss           | 0.292         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 57            |
# |    iterations           | 12            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 1.8342398e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00651       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0633        |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000188     |
# |    value_loss           | 0.15          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 13           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 1664         |
# | train/                  |              |
# |    approx_kl            | 2.705492e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00946     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0899       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 3.52e-05     |
# |    value_loss           | 0.206        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 58            |
# |    iterations           | 14            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 1792          |
# | train/                  |               |
# |    approx_kl            | 2.7706847e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0238       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.135         |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -9.2e-05      |
# |    value_loss           | 0.467         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 59            |
# |    iterations           | 15            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 1920          |
# | train/                  |               |
# |    approx_kl            | 2.6100315e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0241       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.171         |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000225     |
# |    value_loss           | 0.334         |
# -------------------------------------------
# self.n_calls:  2000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 58            |
# |    iterations           | 16            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 1.7108396e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0116        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0592        |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -3.82e-05     |
# |    value_loss           | 0.166         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 59            |
# |    iterations           | 17            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 2176          |
# | train/                  |               |
# |    approx_kl            | 3.1841919e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0137       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0939        |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000234     |
# |    value_loss           | 0.215         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 59           |
# |    iterations           | 18           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 2.540648e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.199        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0483       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000116    |
# |    value_loss           | 0.101        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 59            |
# |    iterations           | 19            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 2432          |
# | train/                  |               |
# |    approx_kl            | 8.0512837e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0512        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.104         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 1.97e-06      |
# |    value_loss           | 0.212         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 59           |
# |    iterations           | 20           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 1.787208e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.0005      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.447        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000162    |
# |    value_loss           | 0.785        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 59            |
# |    iterations           | 21            |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 2688          |
# | train/                  |               |
# |    approx_kl            | 1.7778948e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0175       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0506        |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -7.82e-05     |
# |    value_loss           | 0.111         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 59            |
# |    iterations           | 22            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 2816          |
# | train/                  |               |
# |    approx_kl            | 8.8848174e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0113       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0939        |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -2.92e-05     |
# |    value_loss           | 0.178         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 60            |
# |    iterations           | 23            |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 2944          |
# | train/                  |               |
# |    approx_kl            | 2.7311035e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0033       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.102         |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000171     |
# |    value_loss           | 0.233         |
# -------------------------------------------
# self.n_calls:  3000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 59            |
# |    iterations           | 24            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 3.6512502e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00031      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.837         |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000292     |
# |    value_loss           | 1.41          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 59            |
# |    iterations           | 25            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 3200          |
# | train/                  |               |
# |    approx_kl            | 5.6596473e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00907      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0776        |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000408     |
# |    value_loss           | 0.154         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 59            |
# |    iterations           | 26            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 3328          |
# | train/                  |               |
# |    approx_kl            | 3.5059638e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00815       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.105         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000184     |
# |    value_loss           | 0.212         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 27           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 3456         |
# | train/                  |              |
# |    approx_kl            | 1.966022e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.011        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.047        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000148    |
# |    value_loss           | 0.131        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 28           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 2.459623e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00366      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0579       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000182    |
# |    value_loss           | 0.145        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 29           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 3712         |
# | train/                  |              |
# |    approx_kl            | 3.757421e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00844      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.127        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000199    |
# |    value_loss           | 0.228        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 60            |
# |    iterations           | 30            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 3840          |
# | train/                  |               |
# |    approx_kl            | 3.3332035e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00294      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0565        |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000236     |
# |    value_loss           | 0.119         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 31           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 3968         |
# | train/                  |              |
# |    approx_kl            | 2.163928e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.016        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.253        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000161    |
# |    value_loss           | 0.572        |
# ------------------------------------------
# self.n_calls:  4000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 60            |
# |    iterations           | 32            |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 3.5506673e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00154       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.104         |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000285     |
# |    value_loss           | 0.165         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 33           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 4224         |
# | train/                  |              |
# |    approx_kl            | 3.197696e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00929      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0414       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000218    |
# |    value_loss           | 0.0885       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 60            |
# |    iterations           | 34            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 4352          |
# | train/                  |               |
# |    approx_kl            | 1.9143336e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0135       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.157         |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -3.39e-05     |
# |    value_loss           | 0.284         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 35           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 4480         |
# | train/                  |              |
# |    approx_kl            | 4.630536e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.0251      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.093        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000351    |
# |    value_loss           | 0.154        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 60            |
# |    iterations           | 36            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 3.2344833e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00743      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0791        |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000251     |
# |    value_loss           | 0.17          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 60            |
# |    iterations           | 37            |
# |    time_elapsed         | 77            |
# |    total_timesteps      | 4736          |
# | train/                  |               |
# |    approx_kl            | 2.4642795e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00226      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0748        |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000169     |
# |    value_loss           | 0.134         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 38           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 2.085697e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00802     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0884       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000158    |
# |    value_loss           | 0.16         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 60            |
# |    iterations           | 39            |
# |    time_elapsed         | 82            |
# |    total_timesteps      | 4992          |
# | train/                  |               |
# |    approx_kl            | 1.2498349e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0122       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.123         |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -8.51e-05     |
# |    value_loss           | 0.267         |
# -------------------------------------------
# self.n_calls:  5000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 60            |
# |    iterations           | 40            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 3.9893202e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00425      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.139         |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000288     |
# |    value_loss           | 0.226         |
# -------------------------------------------

# %%
model = PPO.load(".\\monitor_log\\best_model\\model_5000.zip")

obs = env.reset()
obs = obs.copy()

done = True
while True:
    if done:
        state = env.reset()
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    obs=obs.copy()
    env.render()
