# %%
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import time 
from matplotlib import pyplot as plt
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env


env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

tensorboard_log = r'./tensorboard_log/'

model = PPO("CnnPolicy", env, verbose=1,
        tensorboard_log=tensorboard_log)
model.learn(total_timesteps=25000)
model.save("Mario_1")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./tensorboard_log/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 186  |
# |    iterations      | 1    |
# |    time_elapsed    | 10   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 2           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.040014263 |
# |    clip_fraction        | 0.348       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | -0.00238    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.0263      |
# |    value_loss           | 17.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 3            |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0063122995 |
# |    clip_fraction        | 0.0834       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | -0.212       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.1          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000167    |
# |    value_loss           | 0.405        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 84         |
# |    iterations           | 4          |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01045259 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.91      |
# |    explained_variance   | 0.324      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0716     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0104    |
# |    value_loss           | 0.217      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 5          |
# |    time_elapsed         | 129        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.02352254 |
# |    clip_fraction        | 0.398      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.81      |
# |    explained_variance   | 0.0729     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.157      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | 0.0245     |
# |    value_loss           | 4.82       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 6           |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.026102612 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.342       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 7.38        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 7          |
# |    time_elapsed         | 186        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01837607 |
# |    clip_fraction        | 0.222      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.89      |
# |    explained_variance   | 0.535      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.234      |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.000464  |
# |    value_loss           | 1.87       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 8           |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014672004 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.169       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00973    |
# |    value_loss           | 1.38        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.77e+04   |
# |    ep_rew_mean          | 1.05e+03   |
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 9          |
# |    time_elapsed         | 245        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00984725 |
# |    clip_fraction        | 0.181      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.83      |
# |    explained_variance   | 0.15       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0841     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0022    |
# |    value_loss           | 0.743      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.77e+04   |
# |    ep_rew_mean          | 1.05e+03   |
# | time/                   |            |
# |    fps                  | 74         |
# |    iterations           | 10         |
# |    time_elapsed         | 274        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.02412431 |
# |    clip_fraction        | 0.292      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.85      |
# |    explained_variance   | 0.426      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.9        |
# |    n_updates            | 90         |
# |    policy_gradient_loss | 0.00364    |
# |    value_loss           | 8.89       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.77e+04    |
# |    ep_rew_mean          | 1.05e+03    |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 11          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010997508 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0606      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.319       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.77e+04   |
# |    ep_rew_mean          | 1.05e+03   |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 12         |
# |    time_elapsed         | 333        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01239985 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.87      |
# |    explained_variance   | 0.753      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0185     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0226    |
# |    value_loss           | 0.195      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.77e+04   |
# |    ep_rew_mean          | 1.05e+03   |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 13         |
# |    time_elapsed         | 364        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01793627 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.86      |
# |    explained_variance   | 0.586      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0427    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0377    |
# |    value_loss           | 0.158      |
# ----------------------------------------
